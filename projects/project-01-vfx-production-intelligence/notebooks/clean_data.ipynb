# %% [markdown]
# # VFX Production Intelligence Dashboard — Clean and Validate Analytical Data
#
# Use the Guide tab for the full task. Keep this notebook focused on your code, outputs, decisions, and validation notes.

# %%
from pathlib import Path
PROJECT_DIR = Path(r'C:/Users/Dan/Documents/MEGA/Dev/GitHub/career-accelerator/projects/project-01-vfx-production-intelligence')
RAW_DIR = PROJECT_DIR / 'data' / 'raw'
PROCESSED_DIR = PROJECT_DIR / 'data' / 'processed'
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)
PROJECT_DIR
# Out:
# WindowsPath('C:/Users/Dan/Documents/MEGA/Dev/GitHub/career-accelerator/projects/project-01-vfx-production-intelligence')

# %% [markdown]
# ## 1. Profile the raw data
#
# Record the issues you find before changing anything.

# %%
# Write your profiling code or DuckDB SQL here.

# %% [markdown]
# ## 2. Decide how each issue should be handled
#
# Explain why the chosen treatment is appropriate.

# %%
# Write your cleaning transformations here.

# %% [markdown]
# ## 3. Validate the cleaned results
#
# Compare row counts, keys, relationships, categories, ranges, and business rules.

# %%
# Write before-and-after validation checks here.

# %% [markdown]
# ## 4. Export cleaned datasets
#
# Save only reviewed outputs under `data/processed/`.

# %%
# Export your reviewed cleaned tables here.

# %% [markdown]
# ## Cleaning summary
#
# What changed, why, and what remains unresolved?
