# %% [markdown]
# # VFX Production Intelligence Dashboard — Exploratory Analysis
#
# Use the Guide tab for the full task. Keep this notebook focused on your code, outputs, decisions, and validation notes.

# %%
from pathlib import Path
PROJECT_DIR = Path(r'C:/Users/Dan/Documents/MEGA/Dev/GitHub/career-accelerator/projects/project-01-vfx-production-intelligence')
RAW_DIR = PROJECT_DIR / 'data' / 'raw'
PROCESSED_DIR = PROJECT_DIR / 'data' / 'processed'
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)
PROJECT_DIR

# %% [markdown]
# ## Coverage and distributions

# %%
# Explore coverage, distributions, and important categories here.

# %% [markdown]
# ## Segments, time patterns, and relationships

# %%
# Explore patterns tied to the approved business questions.

# %% [markdown]
# ## Anomalies and follow-up questions

# %%
# Investigate unusual records without assuming they are errors.

# %% [markdown]
# ## Candidate findings
#
# Separate observations, hypotheses, and validated findings.
